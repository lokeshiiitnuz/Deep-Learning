# %%
a = [0]
b = [0]

# %%
a.corr(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-d06cf9cd81be> in <module>
# ----> 1 a.corr(b)
#
# AttributeError: 'list' object has no attribute 'corr'
